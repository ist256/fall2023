# %%
import requests 
import pandas as pd

url = "https://api.the-odds-api.com/v4/sports/upcoming/odds/?regions=us&markets=h2h&oddsFormat=american&apiKey=01e3d95f63d2ed8a188c6082e8abb9e7"

response = requests.get(url)
data = response.json()
df = pd.json_normalize(data)
df
# Out:
#                                   id                      sport_key  \
# 0   e9b98c58eee8161fd23c980978a7a157   icehockey_sweden_allsvenskan
# 1   e262e13d2ca1ba6f63c931d27619d9a8       soccer_denmark_superliga
# 2   7dbe053c76eb1cfe17b2332d8b34590c     soccer_greece_super_league
# 3   c85a29ee464144ff2ede325fa9251cdf  soccer_spain_segunda_division
# 4   10438aa27692cda7e65084d68b9c0f33                  soccer_fa_cup
# 5   9bb87c27c34daf8f159ac5c97aecf806           soccer_italy_serie_a
# 6   9d9c394b07e811ea678eed4b665bda5e           soccer_spain_la_liga
# 7   c9c0809f060d334e75c714e12c0cea8f  soccer_portugal_primeira_liga
# 8   3c2016d7ddfb390d33baab17e490f415               basketball_ncaab
# 9   4fce1e478a63822567a2e91da43eafc5                  icehockey_nhl
# 10  9e1106d0c7aa030488e473ea231e5315               basketball_ncaab
# 11  3f1ac976269cdd473489c6b80c1f11db                  icehockey_nhl
# 12  4e1c59771863d6ae1a2904c76576cb14                 basketball_nba
# ...
