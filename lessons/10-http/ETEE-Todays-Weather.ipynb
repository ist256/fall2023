# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    headers = { "user-agent" : "ist256 example mafudge" }
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string, headers=headers)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 8914331,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 14,
#   'importance': 0.5767762857760727,
#   'addresstype': 'city',
#   'name': 'City of Syracuse',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'boundingbox': ['42.9841650', '43.0861210', '-76.2046290', '-76.0742730']}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -18000,
#  'current': {'dt': 1700182129,
#   'sunrise': 1700135890,
#   'sunset': 1700170843,
#   'temp': 47.44,
#   'feels_like': 45.48,
#   'pressure': 1018,
#   'humidity': 70,
#   'dew_point': 38.17,
#   'uvi': 0,
#   'clouds': 40,
#   'visibility': 10000,
#   'wind_speed': 4.61,
#   'wind_deg': 80,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}]},
#  'minutely': [{'dt': 1700182140, 'precipitation': 0},
#   {'dt': 1700182200, 'precipitation': 0},
#   {'dt': 1700182260, 'precipitation': 0},
#   {'dt': 1700182320, 'precipitation': 0},
#   {'dt': 1700182380, 'precipitation': 0},
#   {'dt': 1700182440, 'precipitation': 0},
#   {'dt': 1700182500, 'precipitation': 0},
#   {'dt': 1700182560, 'precipitation': 0},
#   {'dt': 1700182620, 'precipitation': 0},
#   {'dt': 1700182680, 'precipitation': 0},
#   {'dt': 1700182740, 'precipitation': 0},
#   {'dt': 1700182800, 'precipitation': 0},
#   {'dt': 1700182860, 'precipitation': 0},
#   {'dt': 1700182920, 'precipitation': 0},
#   {'dt': 1700182980, 'precipitation': 0},
#   {'dt': 1700183040, 'precipitation': 0},
#   {'dt': 1700183100, 'precipitation': 0},
#   {'dt': 1700183160, 'precipitation': 0},
#   {'dt': 1700183220, 'precipitation': 0},
#   {'dt': 1700183280, 'precipitation': 0},
#   {'dt': 1700183340, 'precipitation': 0},
#   {'dt': 1700183400, 'precipitation': 0},
#   {'dt': 1700183460, 'precipitation': 0},
#   {'dt': 1700183520, 'precipitation': 0},
#   {'dt': 1700183580, 'precipitation': 0},
#   {'dt': 1700183640, 'precipitation': 0},
#   {'dt': 1700183700, 'precipitation': 0},
#   {'dt': 1700183760, 'precipitation': 0},
#   {'dt': 1700183820, 'precipitation': 0},
#   {'dt': 1700183880, 'precipitation': 0},
#   {'dt': 1700183940, 'precipitation': 0},
#   {'dt': 1700184000, 'precipitation': 0},
#   {'dt': 1700184060, 'precipitation': 0},
#   {'dt': 1700184120, 'precipitation': 0},
#   {'dt': 1700184180, 'precipitation': 0},
#   {'dt': 1700184240, 'precipitation': 0},
#   {'dt': 1700184300, 'precipitation': 0},
#   {'dt': 1700184360, 'precipitation': 0},
#   {'dt': 1700184420, 'precipitation': 0},
#   {'dt': 1700184480, 'precipitation': 0},
#   {'dt': 1700184540, 'precipitation': 0},
#   {'dt': 1700184600, 'precipitation': 0},
#   {'dt': 1700184660, 'precipitation': 0},
#   {'dt': 1700184720, 'precipitation': 0},
#   {'dt': 1700184780, 'precipitation': 0},
#   {'dt': 1700184840, 'precipitation': 0},
#   {'dt': 1700184900, 'precipitation': 0},
#   {'dt': 1700184960, 'precipitation': 0},
#   {'dt': 1700185020, 'precipitation': 0},
#   {'dt': 1700185080, 'precipitation': 0},
#   {'dt': 1700185140, 'precipitation': 0},
#   {'dt': 1700185200, 'precipitation': 0},
#   {'dt': 1700185260, 'precipitation': 0},
#   {'dt': 1700185320, 'precipitation': 0},
#   {'dt': 1700185380, 'precipitation': 0},
#   {'dt': 1700185440, 'precipitation': 0},
#   {'dt': 1700185500, 'precipitation': 0},
#   {'dt': 1700185560, 'precipitation': 0},
#   {'dt': 1700185620, 'precipitation': 0},
#   {'dt': 1700185680, 'precipitation': 0}],
#  'hourly': [{'dt': 1700179200,
#    'temp': 47.53,
#    'feels_like': 44.46,
#    'pressure': 1018,
#    'humidity': 71,
#    'dew_point': 38.61,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 6.51,
#    'wind_deg': 162,
#    'wind_gust': 12.26,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1700182800,
#    'temp': 47.44,
#    'feels_like': 44.06,
#    'pressure': 1018,
#    'humidity': 70,
#    'dew_point': 38.17,
#    'uvi': 0,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 7.09,
#    'wind_deg': 167,
#    'wind_gust': 18.61,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1700186400,
#    'temp': 47.48,
#    'feels_like': 44.22,
#    'pressure': 1018,
#    'humidity': 72,
#    'dew_point': 38.91,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 6.85,
#    'wind_deg': 173,
#    'wind_gust': 18.01,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1700190000,
#    'temp': 47.41,
#    'feels_like': 43.88,
#    'pressure': 1018,
#    'humidity': 73,
#    'dew_point': 39.2,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 7.4,
#    'wind_deg': 174,
#    'wind_gust': 20.45,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1700193600,
#    'temp': 48.33,
#    'feels_like': 44.06,
#    'pressure': 1017,
#    'humidity': 69,
#    'dew_point': 38.64,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 9.73,
#    'wind_deg': 176,
#    'wind_gust': 28.34,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1700197200,
#    'temp': 50.07,
#    'feels_like': 47.73,
#    'pressure': 1017,
#    'humidity': 63,
#    'dew_point': 37.99,
#    'uvi': 0,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 10.83,
#    'wind_deg': 181,
#    'wind_gust': 30.85,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700200800,
#    'temp': 51.31,
#    'feels_like': 48.97,
#    'pressure': 1016,
#    'humidity': 60,
#    'dew_point': 37,
#    'uvi': 0,
#    'clouds': 71,
#    'visibility': 10000,
#    'wind_speed': 11.05,
#    'wind_deg': 183,
#    'wind_gust': 32.21,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700204400,
#    'temp': 51.8,
#    'feels_like': 49.41,
#    'pressure': 1015,
#    'humidity': 58,
#    'dew_point': 36.55,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 11.56,
#    'wind_deg': 186,
#    'wind_gust': 32.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700208000,
#    'temp': 52.07,
#    'feels_like': 49.6,
#    'pressure': 1014,
#    'humidity': 56,
#    'dew_point': 35.73,
#    'uvi': 0,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 12.28,
#    'wind_deg': 188,
#    'wind_gust': 34.18,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700211600,
#    'temp': 52.45,
#    'feels_like': 49.93,
#    'pressure': 1014,
#    'humidity': 54,
#    'dew_point': 35.2,
#    'uvi': 0,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 12.53,
#    'wind_deg': 187,
#    'wind_gust': 33.71,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700215200,
#    'temp': 52.84,
#    'feels_like': 50.27,
#    'pressure': 1013,
#    'humidity': 52,
#    'dew_point': 34.74,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 12.46,
#    'wind_deg': 188,
#    'wind_gust': 34,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700218800,
#    'temp': 53.22,
#    'feels_like': 50.54,
#    'pressure': 1013,
#    'humidity': 49,
#    'dew_point': 33.76,
#    'uvi': 0,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 12.48,
#    'wind_deg': 192,
#    'wind_gust': 35.1,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1700222400,
#    'temp': 53.82,
#    'feels_like': 51.1,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 33.1,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 14.27,
#    'wind_deg': 193,
#    'wind_gust': 37.16,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700226000,
#    'temp': 54.23,
#    'feels_like': 51.57,
#    'pressure': 1012,
#    'humidity': 47,
#    'dew_point': 33.62,
#    'uvi': 0.07,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.26,
#    'wind_deg': 193,
#    'wind_gust': 38.48,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700229600,
#    'temp': 55.81,
#    'feels_like': 53.26,
#    'pressure': 1011,
#    'humidity': 46,
#    'dew_point': 34.5,
#    'uvi': 0.3,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.35,
#    'wind_deg': 192,
#    'wind_gust': 39.12,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700233200,
#    'temp': 56.34,
#    'feels_like': 53.83,
#    'pressure': 1010,
#    'humidity': 46,
#    'dew_point': 35.31,
#    'uvi': 0.56,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.71,
#    'wind_deg': 191,
#    'wind_gust': 39.71,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700236800,
#    'temp': 58.86,
#    'feels_like': 56.7,
#    'pressure': 1009,
#    'humidity': 48,
#    'dew_point': 38.25,
#    'uvi': 0.48,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.18,
#    'wind_deg': 195,
#    'wind_gust': 38.63,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700240400,
#    'temp': 59.54,
#    'feels_like': 57.6,
#    'pressure': 1008,
#    'humidity': 51,
#    'dew_point': 40.57,
#    'uvi': 1.15,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.63,
#    'wind_deg': 194,
#    'wind_gust': 39.39,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.02},
#   {'dt': 1700244000,
#    'temp': 60.08,
#    'feels_like': 58.37,
#    'pressure': 1007,
#    'humidity': 55,
#    'dew_point': 43.27,
#    'uvi': 0.37,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.48,
#    'wind_deg': 203,
#    'wind_gust': 38.14,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.23},
#   {'dt': 1700247600,
#    'temp': 56.34,
#    'feels_like': 54.97,
#    'pressure': 1007,
#    'humidity': 70,
#    'dew_point': 45.99,
#    'uvi': 0.07,
#    'clouds': 100,
#    'visibility': 7807,
#    'wind_speed': 15.82,
#    'wind_deg': 212,
#    'wind_gust': 35.34,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.82,
#    'rain': {'1h': 1.07}},
#   {'dt': 1700251200,
#    'temp': 53.94,
#    'feels_like': 52.84,
#    'pressure': 1007,
#    'humidity': 81,
#    'dew_point': 47.34,
#    'uvi': 0.04,
#    'clouds': 100,
#    'visibility': 6883,
#    'wind_speed': 16.44,
#    'wind_deg': 203,
#    'wind_gust': 37.92,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.97,
#    'rain': {'1h': 2.14}},
#   {'dt': 1700254800,
#    'temp': 53.46,
#    'feels_like': 52.39,
#    'pressure': 1007,
#    'humidity': 83,
#    'dew_point': 47.57,
#    'uvi': 0.02,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.79,
#    'wind_deg': 205,
#    'wind_gust': 37.4,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.99,
#    'rain': {'1h': 2.07}},
#   {'dt': 1700258400,
#    'temp': 53.94,
#    'feels_like': 52.99,
#    'pressure': 1007,
#    'humidity': 84,
#    'dew_point': 48.54,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.76,
#    'wind_deg': 202,
#    'wind_gust': 37.78,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.86}},
#   {'dt': 1700262000,
#    'temp': 54.1,
#    'feels_like': 53.2,
#    'pressure': 1007,
#    'humidity': 85,
#    'dew_point': 48.79,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.21,
#    'wind_deg': 213,
#    'wind_gust': 33.82,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.47}},
#   {'dt': 1700265600,
#    'temp': 51.6,
#    'feels_like': 50.79,
#    'pressure': 1009,
#    'humidity': 92,
#    'dew_point': 48.43,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 10.74,
#    'wind_deg': 283,
#    'wind_gust': 21.54,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.63}},
#   {'dt': 1700269200,
#    'temp': 48.7,
#    'feels_like': 44.56,
#    'pressure': 1010,
#    'humidity': 95,
#    'dew_point': 46.53,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 5398,
#    'wind_speed': 9.6,
#    'wind_deg': 296,
#    'wind_gust': 18.99,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.99}},
#   {'dt': 1700272800,
#    'temp': 47.16,
#    'feels_like': 42.48,
#    'pressure': 1010,
#    'humidity': 93,
#    'dew_point': 44.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7840,
#    'wind_speed': 10.09,
#    'wind_deg': 297,
#    'wind_gust': 18.21,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.12}},
#   {'dt': 1700276400,
#    'temp': 46.08,
#    'feels_like': 41.29,
#    'pressure': 1011,
#    'humidity': 91,
#    'dew_point': 42.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 9.71,
#    'wind_deg': 299,
#    'wind_gust': 17.92,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.7}},
#   {'dt': 1700280000,
#    'temp': 45.37,
#    'feels_like': 40.73,
#    'pressure': 1011,
#    'humidity': 87,
#    'dew_point': 40.95,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.9,
#    'wind_deg': 293,
#    'wind_gust': 18.12,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.25}},
#   {'dt': 1700283600,
#    'temp': 45.18,
#    'feels_like': 40.39,
#    'pressure': 1010,
#    'humidity': 87,
#    'dew_point': 40.68,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 9.15,
#    'wind_deg': 296,
#    'wind_gust': 17.69,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.8},
#   {'dt': 1700287200,
#    'temp': 44.55,
#    'feels_like': 39.31,
#    'pressure': 1011,
#    'humidity': 85,
#    'dew_point': 39.47,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 9.93,
#    'wind_deg': 307,
#    'wind_gust': 16.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.8},
#   {'dt': 1700290800,
#    'temp': 43.05,
#    'feels_like': 37.6,
#    'pressure': 1011,
#    'humidity': 88,
#    'dew_point': 38.95,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 9.57,
#    'wind_deg': 333,
#    'wind_gust': 16.28,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.14},
#   {'dt': 1700294400,
#    'temp': 42.03,
#    'feels_like': 36.86,
#    'pressure': 1011,
#    'humidity': 88,
#    'dew_point': 37.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.39,
#    'wind_deg': 335,
#    'wind_gust': 16.46,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.06},
#   {'dt': 1700298000,
#    'temp': 41.2,
#    'feels_like': 35.94,
#    'pressure': 1012,
#    'humidity': 85,
#    'dew_point': 36.25,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.21,
#    'wind_deg': 344,
#    'wind_gust': 15.46,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.05},
#   {'dt': 1700301600,
#    'temp': 39.87,
#    'feels_like': 34.02,
#    'pressure': 1012,
#    'humidity': 84,
#    'dew_point': 34.48,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 8.81,
#    'wind_deg': 345,
#    'wind_gust': 15.79,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.05},
#   {'dt': 1700305200,
#    'temp': 37.92,
#    'feels_like': 31.35,
#    'pressure': 1013,
#    'humidity': 79,
#    'dew_point': 31.23,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 9.4,
#    'wind_deg': 353,
#    'wind_gust': 16.51,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.01},
#   {'dt': 1700308800,
#    'temp': 36.43,
#    'feels_like': 30.2,
#    'pressure': 1013,
#    'humidity': 74,
#    'dew_point': 28,
#    'uvi': 0,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 8.08,
#    'wind_deg': 358,
#    'wind_gust': 16.69,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.01},
#   {'dt': 1700312400,
#    'temp': 36.03,
#    'feels_like': 29.7,
#    'pressure': 1014,
#    'humidity': 71,
#    'dew_point': 26.74,
#    'uvi': 0.11,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 8.12,
#    'wind_deg': 3,
#    'wind_gust': 16.51,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700316000,
#    'temp': 36.63,
#    'feels_like': 30.07,
#    'pressure': 1014,
#    'humidity': 67,
#    'dew_point': 26.02,
#    'uvi': 0.45,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 8.75,
#    'wind_deg': 360,
#    'wind_gust': 15.5,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700319600,
#    'temp': 37.74,
#    'feels_like': 31.12,
#    'pressure': 1013,
#    'humidity': 66,
#    'dew_point': 26.58,
#    'uvi': 0.95,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 9.4,
#    'wind_deg': 346,
#    'wind_gust': 15.59,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700323200,
#    'temp': 39.13,
#    'feels_like': 32.45,
#    'pressure': 1013,
#    'humidity': 63,
#    'dew_point': 26.89,
#    'uvi': 1.43,
#    'clouds': 69,
#    'visibility': 10000,
#    'wind_speed': 10.25,
#    'wind_deg': 336,
#    'wind_gust': 15.32,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700326800,
#    'temp': 40.53,
#    'feels_like': 34.2,
#    'pressure': 1012,
#    'humidity': 57,
#    'dew_point': 25.74,
#    'uvi': 1.66,
#    'clouds': 71,
#    'visibility': 10000,
#    'wind_speed': 10.25,
#    'wind_deg': 336,
#    'wind_gust': 14.74,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700330400,
#    'temp': 41.18,
#    'feels_like': 34.34,
#    'pressure': 1011,
#    'humidity': 54,
#    'dew_point': 24.94,
#    'uvi': 1.48,
#    'clouds': 63,
#    'visibility': 10000,
#    'wind_speed': 11.99,
#    'wind_deg': 325,
#    'wind_gust': 16.46,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1700334000,
#    'temp': 40.68,
#    'feels_like': 33.67,
#    'pressure': 1011,
#    'humidity': 54,
#    'dew_point': 24.55,
#    'uvi': 1.05,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 12.08,
#    'wind_deg': 319,
#    'wind_gust': 16.62,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1700337600,
#    'temp': 39.81,
#    'feels_like': 33.08,
#    'pressure': 1011,
#    'humidity': 56,
#    'dew_point': 24.62,
#    'uvi': 0.52,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 10.78,
#    'wind_deg': 313,
#    'wind_gust': 15.3,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1700341200,
#    'temp': 38.46,
#    'feels_like': 32.23,
#    'pressure': 1011,
#    'humidity': 62,
#    'dew_point': 25.57,
#    'uvi': 0.16,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 8.93,
#    'wind_deg': 308,
#    'wind_gust': 15.37,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1700344800,
#    'temp': 36.21,
#    'feels_like': 31.01,
#    'pressure': 1011,
#    'humidity': 68,
#    'dew_point': 25.66,
#    'uvi': 0,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 6.33,
#    'wind_deg': 296,
#    'wind_gust': 15.35,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0},
#   {'dt': 1700348400,
#    'temp': 35.22,
#    'feels_like': 30.78,
#    'pressure': 1011,
#    'humidity': 71,
#    'dew_point': 26.01,
#    'uvi': 0,
#    'clouds': 8,
#    'visibility': 10000,
#    'wind_speed': 5.1,
#    'wind_deg': 274,
#    'wind_gust': 13.13,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1700150400,
#    'sunrise': 1700135890,
#    'sunset': 1700170843,
#    'moonrise': 1700149500,
#    'moonset': 1700179380,
#    'moon_phase': 0.11,
#    'temp': {'day': 53.33,
#     'min': 40.33,
#     'max': 57.4,
#     'night': 48.33,
#     'eve': 48.9,
#     'morn': 40.93},
#    'feels_like': {'day': 50.85, 'night': 44.06, 'eve': 46.96, 'morn': 38.25},
#    'pressure': 1023,
#    'humidity': 53,
#    'dew_point': 35.64,
#    'wind_speed': 9.73,
#    'wind_deg': 176,
#    'wind_gust': 28.34,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 25,
#    'pop': 0,
#    'uvi': 1.62},
#   {'dt': 1700236800,
#    'sunrise': 1700222367,
#    'sunset': 1700257191,
#    'moonrise': 1700239260,
#    'moonset': 1700269980,
#    'moon_phase': 0.15,
#    'temp': {'day': 58.86,
#     'min': 45.37,
#     'max': 60.08,
#     'night': 45.37,
#     'eve': 53.94,
#     'morn': 52.84},
#    'feels_like': {'day': 56.7, 'night': 40.73, 'eve': 52.99, 'morn': 50.27},
#    'pressure': 1009,
#    'humidity': 48,
#    'dew_point': 38.25,
#    'wind_speed': 18.63,
#    'wind_deg': 194,
#    'wind_gust': 39.71,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 10.3,
#    'uvi': 1.15},
#   {'dt': 1700323200,
#    'sunrise': 1700308843,
#    'sunset': 1700343541,
#    'moonrise': 1700328240,
#    'moonset': 1700361000,
#    'moon_phase': 0.19,
#    'temp': {'day': 39.13,
#     'min': 34.74,
#     'max': 45.18,
#     'night': 35.98,
#     'eve': 36.21,
#     'morn': 39.87},
#    'feels_like': {'day': 32.45, 'night': 28.49, 'eve': 31.01, 'morn': 34.02},
#    'pressure': 1013,
#    'humidity': 63,
#    'dew_point': 26.89,
#    'wind_speed': 12.08,
#    'wind_deg': 319,
#    'wind_gust': 28.86,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 69,
#    'pop': 0.8,
#    'uvi': 1.66},
#   {'dt': 1700409600,
#    'sunrise': 1700395318,
#    'sunset': 1700429892,
#    'moonrise': 1700416740,
#    'moonset': 1700452080,
#    'moon_phase': 0.22,
#    'temp': {'day': 39.88,
#     'min': 32.88,
#     'max': 40.53,
#     'night': 32.88,
#     'eve': 38.28,
#     'morn': 40.53},
#    'feels_like': {'day': 32.49, 'night': 29.01, 'eve': 30.27, 'morn': 32.83},
#    'pressure': 1011,
#    'humidity': 71,
#    'dew_point': 29.88,
#    'wind_speed': 14.38,
#    'wind_deg': 261,
#    'wind_gust': 32.01,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 99,
#    'pop': 0.48,
#    'rain': 0.84,
#    'snow': 1.75,
#    'uvi': 1.34},
#   {'dt': 1700496000,
#    'sunrise': 1700481793,
#    'sunset': 1700516246,
#    'moonrise': 1700504820,
#    'moonset': 0,
#    'moon_phase': 0.25,
#    'temp': {'day': 32.68,
#     'min': 27.82,
#     'max': 35.74,
#     'night': 29.93,
#     'eve': 33.85,
#     'morn': 28.94},
#    'feels_like': {'day': 29.53, 'night': 29.93, 'eve': 33.85, 'morn': 28.94},
#    'pressure': 1027,
#    'humidity': 53,
#    'dew_point': 16.38,
#    'wind_speed': 3.69,
#    'wind_deg': 338,
#    'wind_gust': 8.23,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 48,
#    'pop': 0,
#    'uvi': 1.43},
#   {'dt': 1700582400,
#    'sunrise': 1700568268,
#    'sunset': 1700602601,
#    'moonrise': 1700592600,
#    'moonset': 1700543100,
#    'moon_phase': 0.3,
#    'temp': {'day': 37.08,
#     'min': 29.05,
#     'max': 40.28,
#     'night': 35.76,
#     'eve': 37.92,
#     'morn': 29.19},
#    'feels_like': {'day': 29.52, 'night': 25.05, 'eve': 28.99, 'morn': 23.52},
#    'pressure': 1027,
#    'humidity': 49,
#    'dew_point': 18.9,
#    'wind_speed': 19.53,
#    'wind_deg': 121,
#    'wind_gust': 46.53,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 85,
#    'pop': 1,
#    'rain': 8.37,
#    'uvi': 2},
#   {'dt': 1700668800,
#    'sunrise': 1700654742,
#    'sunset': 1700688959,
#    'moonrise': 1700680320,
#    'moonset': 1700634060,
#    'moon_phase': 0.33,
#    'temp': {'day': 42.48,
#     'min': 28.69,
#     'max': 42.48,
#     'night': 28.69,
#     'eve': 36.5,
#     'morn': 37.49},
#    'feels_like': {'day': 35.44, 'night': 19.09, 'eve': 28.76, 'morn': 28.22},
#    'pressure': 1001,
#    'humidity': 88,
#    'dew_point': 38.26,
#    'wind_speed': 23.96,
#    'wind_deg': 126,
#    'wind_gust': 52.66,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 17.01,
#    'uvi': 2},
#   {'dt': 1700755200,
#    'sunrise': 1700741215,
#    'sunset': 1700775319,
#    'moonrise': 1700767980,
#    'moonset': 1700724960,
#    'moon_phase': 0.37,
#    'temp': {'day': 27.75,
#     'min': 22.75,
#     'max': 29.17,
#     'night': 22.75,
#     'eve': 27.05,
#     'morn': 26.2},
#    'feels_like': {'day': 16.3, 'night': 11.48, 'eve': 16.95, 'morn': 16.92},
#    'pressure': 1008,
#    'humidity': 61,
#    'dew_point': 15.03,
#    'wind_speed': 14.61,
#    'wind_deg': 246,
#    'wind_gust': 25.86,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 86,
#    'pop': 0.32,
#    'snow': 2.1,
#    'uvi': 2}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily'][0]
# Out:
# {'dt': 1700150400,
#  'sunrise': 1700135890,
#  'sunset': 1700170843,
#  'moonrise': 1700149500,
#  'moonset': 1700179380,
#  'moon_phase': 0.11,
#  'temp': {'day': 53.33,
#   'min': 40.33,
#   'max': 57.4,
#   'night': 48.33,
#   'eve': 48.9,
#   'morn': 40.93},
#  'feels_like': {'day': 50.85, 'night': 44.06, 'eve': 46.96, 'morn': 38.25},
#  'pressure': 1023,
#  'humidity': 53,
#  'dew_point': 35.64,
#  'wind_speed': 9.73,
#  'wind_deg': 176,
#  'wind_gust': 28.34,
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'clouds': 25,
#  'pop': 0,
#  'uvi': 1.62}

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) :  Syracuse, NY
# Current conditions in Syracuse, NY are scattered clouds with a temperature of 47.44 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat, lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', continuous_update=False, description='location'), Button(description='Run…
