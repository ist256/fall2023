# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    headers = { "user-agent" : "ist256 example mafudge" }
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string, headers=headers)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 8914331,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 14,
#   'importance': 0.5767762857760727,
#   'addresstype': 'city',
#   'name': 'City of Syracuse',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'boundingbox': ['42.9841650', '43.0861210', '-76.2046290', '-76.0742730']}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -18000,
#  'current': {'dt': 1699302762,
#   'sunrise': 1699271114,
#   'sunset': 1699307470,
#   'temp': 50.83,
#   'feels_like': 48.34,
#   'pressure': 1013,
#   'humidity': 58,
#   'dew_point': 36.61,
#   'uvi': 0.12,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 6.91,
#   'wind_deg': 60,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1699302780, 'precipitation': 0},
#   {'dt': 1699302840, 'precipitation': 0},
#   {'dt': 1699302900, 'precipitation': 0},
#   {'dt': 1699302960, 'precipitation': 0},
#   {'dt': 1699303020, 'precipitation': 0},
#   {'dt': 1699303080, 'precipitation': 0},
#   {'dt': 1699303140, 'precipitation': 0},
#   {'dt': 1699303200, 'precipitation': 0},
#   {'dt': 1699303260, 'precipitation': 0},
#   {'dt': 1699303320, 'precipitation': 0},
#   {'dt': 1699303380, 'precipitation': 0},
#   {'dt': 1699303440, 'precipitation': 0},
#   {'dt': 1699303500, 'precipitation': 0},
#   {'dt': 1699303560, 'precipitation': 0},
#   {'dt': 1699303620, 'precipitation': 0},
#   {'dt': 1699303680, 'precipitation': 0},
#   {'dt': 1699303740, 'precipitation': 0},
#   {'dt': 1699303800, 'precipitation': 0},
#   {'dt': 1699303860, 'precipitation': 0},
#   {'dt': 1699303920, 'precipitation': 0},
#   {'dt': 1699303980, 'precipitation': 0},
#   {'dt': 1699304040, 'precipitation': 0},
#   {'dt': 1699304100, 'precipitation': 0},
#   {'dt': 1699304160, 'precipitation': 0},
#   {'dt': 1699304220, 'precipitation': 0},
#   {'dt': 1699304280, 'precipitation': 0},
#   {'dt': 1699304340, 'precipitation': 0},
#   {'dt': 1699304400, 'precipitation': 0},
#   {'dt': 1699304460, 'precipitation': 0},
#   {'dt': 1699304520, 'precipitation': 0},
#   {'dt': 1699304580, 'precipitation': 0},
#   {'dt': 1699304640, 'precipitation': 0},
#   {'dt': 1699304700, 'precipitation': 0},
#   {'dt': 1699304760, 'precipitation': 0},
#   {'dt': 1699304820, 'precipitation': 0},
#   {'dt': 1699304880, 'precipitation': 0},
#   {'dt': 1699304940, 'precipitation': 0},
#   {'dt': 1699305000, 'precipitation': 0},
#   {'dt': 1699305060, 'precipitation': 0},
#   {'dt': 1699305120, 'precipitation': 0},
#   {'dt': 1699305180, 'precipitation': 0},
#   {'dt': 1699305240, 'precipitation': 0},
#   {'dt': 1699305300, 'precipitation': 0},
#   {'dt': 1699305360, 'precipitation': 0},
#   {'dt': 1699305420, 'precipitation': 0},
#   {'dt': 1699305480, 'precipitation': 0},
#   {'dt': 1699305540, 'precipitation': 0},
#   {'dt': 1699305600, 'precipitation': 0},
#   {'dt': 1699305660, 'precipitation': 0},
#   {'dt': 1699305720, 'precipitation': 0},
#   {'dt': 1699305780, 'precipitation': 0},
#   {'dt': 1699305840, 'precipitation': 0},
#   {'dt': 1699305900, 'precipitation': 0},
#   {'dt': 1699305960, 'precipitation': 0},
#   {'dt': 1699306020, 'precipitation': 0},
#   {'dt': 1699306080, 'precipitation': 0},
#   {'dt': 1699306140, 'precipitation': 0},
#   {'dt': 1699306200, 'precipitation': 0},
#   {'dt': 1699306260, 'precipitation': 0},
#   {'dt': 1699306320, 'precipitation': 0}],
#  'hourly': [{'dt': 1699300800,
#    'temp': 50.76,
#    'feels_like': 48.22,
#    'pressure': 1013,
#    'humidity': 57,
#    'dew_point': 36.1,
#    'uvi': 0.38,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.79,
#    'wind_deg': 168,
#    'wind_gust': 27.02,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699304400,
#    'temp': 50.83,
#    'feels_like': 48.34,
#    'pressure': 1013,
#    'humidity': 58,
#    'dew_point': 36.61,
#    'uvi': 0.12,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 13.91,
#    'wind_deg': 170,
#    'wind_gust': 29.84,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699308000,
#    'temp': 50.38,
#    'feels_like': 47.89,
#    'pressure': 1013,
#    'humidity': 59,
#    'dew_point': 36.61,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.99,
#    'wind_deg': 172,
#    'wind_gust': 35.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699311600,
#    'temp': 50.22,
#    'feels_like': 47.71,
#    'pressure': 1012,
#    'humidity': 59,
#    'dew_point': 36.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.82,
#    'wind_deg': 174,
#    'wind_gust': 36.78,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699315200,
#    'temp': 49.84,
#    'feels_like': 43.79,
#    'pressure': 1012,
#    'humidity': 62,
#    'dew_point': 37.36,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 17.9,
#    'wind_deg': 184,
#    'wind_gust': 37.09,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.24,
#    'rain': {'1h': 0.3}},
#   {'dt': 1699318800,
#    'temp': 47.68,
#    'feels_like': 40.84,
#    'pressure': 1011,
#    'humidity': 75,
#    'dew_point': 40.15,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.63,
#    'wind_deg': 174,
#    'wind_gust': 40.89,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.27}},
#   {'dt': 1699322400,
#    'temp': 47.8,
#    'feels_like': 40.78,
#    'pressure': 1009,
#    'humidity': 77,
#    'dew_point': 39.97,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 19.71,
#    'wind_deg': 184,
#    'wind_gust': 43.04,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.8},
#   {'dt': 1699326000,
#    'temp': 48.49,
#    'feels_like': 41.38,
#    'pressure': 1009,
#    'humidity': 76,
#    'dew_point': 40.44,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 21.3,
#    'wind_deg': 186,
#    'wind_gust': 43.44,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.8},
#   {'dt': 1699329600,
#    'temp': 49.84,
#    'feels_like': 42.98,
#    'pressure': 1007,
#    'humidity': 74,
#    'dew_point': 41.09,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 22.32,
#    'wind_deg': 188,
#    'wind_gust': 42.41,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.78},
#   {'dt': 1699333200,
#    'temp': 50.67,
#    'feels_like': 48.96,
#    'pressure': 1007,
#    'humidity': 75,
#    'dew_point': 42.1,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 19.77,
#    'wind_deg': 192,
#    'wind_gust': 39.3,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.72},
#   {'dt': 1699336800,
#    'temp': 51.51,
#    'feels_like': 49.89,
#    'pressure': 1006,
#    'humidity': 75,
#    'dew_point': 43.03,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.68,
#    'wind_deg': 192,
#    'wind_gust': 37.38,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.84},
#   {'dt': 1699340400,
#    'temp': 51.8,
#    'feels_like': 50.25,
#    'pressure': 1005,
#    'humidity': 76,
#    'dew_point': 43.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 18.01,
#    'wind_deg': 193,
#    'wind_gust': 37.63,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.06},
#   {'dt': 1699344000,
#    'temp': 51.85,
#    'feels_like': 50.41,
#    'pressure': 1005,
#    'humidity': 78,
#    'dew_point': 44.53,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 16.49,
#    'wind_deg': 197,
#    'wind_gust': 37.36,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.09},
#   {'dt': 1699347600,
#    'temp': 52.2,
#    'feels_like': 50.88,
#    'pressure': 1004,
#    'humidity': 80,
#    'dew_point': 45.34,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 16.02,
#    'wind_deg': 202,
#    'wind_gust': 37.09,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.25},
#   {'dt': 1699351200,
#    'temp': 53.17,
#    'feels_like': 51.94,
#    'pressure': 1004,
#    'humidity': 80,
#    'dew_point': 46.36,
#    'uvi': 0,
#    'clouds': 92,
#    'visibility': 10000,
#    'wind_speed': 14.9,
#    'wind_deg': 206,
#    'wind_gust': 34.05,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.28},
#   {'dt': 1699354800,
#    'temp': 54.32,
#    'feels_like': 53.26,
#    'pressure': 1003,
#    'humidity': 81,
#    'dew_point': 47.75,
#    'uvi': 0,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 14.5,
#    'wind_deg': 211,
#    'wind_gust': 31.65,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.34,
#    'rain': {'1h': 0.1}},
#   {'dt': 1699358400,
#    'temp': 53.51,
#    'feels_like': 52.61,
#    'pressure': 1004,
#    'humidity': 86,
#    'dew_point': 48.7,
#    'uvi': 0,
#    'clouds': 81,
#    'visibility': 10000,
#    'wind_speed': 12.44,
#    'wind_deg': 232,
#    'wind_gust': 31.56,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.42,
#    'rain': {'1h': 0.25}},
#   {'dt': 1699362000,
#    'temp': 55.04,
#    'feels_like': 54.19,
#    'pressure': 1005,
#    'humidity': 84,
#    'dew_point': 49.44,
#    'uvi': 0.15,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 14.07,
#    'wind_deg': 260,
#    'wind_gust': 30.11,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.34}},
#   {'dt': 1699365600,
#    'temp': 55.38,
#    'feels_like': 54.28,
#    'pressure': 1005,
#    'humidity': 78,
#    'dew_point': 47.93,
#    'uvi': 0.51,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 16.04,
#    'wind_deg': 267,
#    'wind_gust': 30.58,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.88,
#    'rain': {'1h': 0.36}},
#   {'dt': 1699369200,
#    'temp': 54.86,
#    'feels_like': 53.67,
#    'pressure': 1006,
#    'humidity': 77,
#    'dew_point': 46.9,
#    'uvi': 1.04,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 15.84,
#    'wind_deg': 272,
#    'wind_gust': 30.69,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.24}},
#   {'dt': 1699372800,
#    'temp': 53.31,
#    'feels_like': 52.02,
#    'pressure': 1007,
#    'humidity': 78,
#    'dew_point': 45.68,
#    'uvi': 0.77,
#    'clouds': 62,
#    'visibility': 10000,
#    'wind_speed': 15.95,
#    'wind_deg': 277,
#    'wind_gust': 30.58,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.27}},
#   {'dt': 1699376400,
#    'temp': 50.85,
#    'feels_like': 49.48,
#    'pressure': 1007,
#    'humidity': 82,
#    'dew_point': 44.58,
#    'uvi': 0.88,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 15.73,
#    'wind_deg': 286,
#    'wind_gust': 28.27,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.9,
#    'rain': {'1h': 0.15}},
#   {'dt': 1699380000,
#    'temp': 48.42,
#    'feels_like': 42.33,
#    'pressure': 1008,
#    'humidity': 79,
#    'dew_point': 41.31,
#    'uvi': 0.81,
#    'clouds': 75,
#    'visibility': 10000,
#    'wind_speed': 16.22,
#    'wind_deg': 284,
#    'wind_gust': 30.31,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0.89},
#   {'dt': 1699383600,
#    'temp': 48.52,
#    'feels_like': 42.53,
#    'pressure': 1009,
#    'humidity': 76,
#    'dew_point': 40.35,
#    'uvi': 0.39,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 15.93,
#    'wind_deg': 290,
#    'wind_gust': 28.05,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.04},
#   {'dt': 1699387200,
#    'temp': 46.94,
#    'feels_like': 40.62,
#    'pressure': 1010,
#    'humidity': 77,
#    'dew_point': 39.16,
#    'uvi': 0.21,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 15.41,
#    'wind_deg': 288,
#    'wind_gust': 27.81,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699390800,
#    'temp': 45.86,
#    'feels_like': 39.31,
#    'pressure': 1011,
#    'humidity': 78,
#    'dew_point': 38.43,
#    'uvi': 0.07,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 15.14,
#    'wind_deg': 294,
#    'wind_gust': 26.91,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699394400,
#    'temp': 44.89,
#    'feels_like': 38.12,
#    'pressure': 1012,
#    'humidity': 74,
#    'dew_point': 36.48,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 14.92,
#    'wind_deg': 293,
#    'wind_gust': 26.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699398000,
#    'temp': 44.38,
#    'feels_like': 37.67,
#    'pressure': 1013,
#    'humidity': 72,
#    'dew_point': 35.17,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 14.23,
#    'wind_deg': 292,
#    'wind_gust': 25.21,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699401600,
#    'temp': 43.95,
#    'feels_like': 37.29,
#    'pressure': 1014,
#    'humidity': 72,
#    'dew_point': 34.48,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 13.62,
#    'wind_deg': 292,
#    'wind_gust': 22.64,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699405200,
#    'temp': 43.14,
#    'feels_like': 36.64,
#    'pressure': 1015,
#    'humidity': 71,
#    'dew_point': 33.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.46,
#    'wind_deg': 304,
#    'wind_gust': 20.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699408800,
#    'temp': 41.65,
#    'feels_like': 34.77,
#    'pressure': 1016,
#    'humidity': 73,
#    'dew_point': 32.61,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 12.41,
#    'wind_deg': 318,
#    'wind_gust': 20.45,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699412400,
#    'temp': 40.57,
#    'feels_like': 33.78,
#    'pressure': 1016,
#    'humidity': 70,
#    'dew_point': 30.58,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.41,
#    'wind_deg': 313,
#    'wind_gust': 18.34,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699416000,
#    'temp': 39.63,
#    'feels_like': 32.47,
#    'pressure': 1017,
#    'humidity': 67,
#    'dew_point': 28.63,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.79,
#    'wind_deg': 314,
#    'wind_gust': 17.67,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699419600,
#    'temp': 38.5,
#    'feels_like': 31.35,
#    'pressure': 1017,
#    'humidity': 68,
#    'dew_point': 27.86,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 10.98,
#    'wind_deg': 321,
#    'wind_gust': 17.02,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699423200,
#    'temp': 37.54,
#    'feels_like': 30.16,
#    'pressure': 1019,
#    'humidity': 66,
#    'dew_point': 26.29,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.01,
#    'wind_deg': 315,
#    'wind_gust': 17.87,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699426800,
#    'temp': 36.72,
#    'feels_like': 29.05,
#    'pressure': 1019,
#    'humidity': 66,
#    'dew_point': 25.56,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.18,
#    'wind_deg': 323,
#    'wind_gust': 18.32,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699430400,
#    'temp': 35.78,
#    'feels_like': 28.27,
#    'pressure': 1019,
#    'humidity': 66,
#    'dew_point': 24.67,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 10.29,
#    'wind_deg': 324,
#    'wind_gust': 17.31,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699434000,
#    'temp': 34.54,
#    'feels_like': 27.09,
#    'pressure': 1020,
#    'humidity': 68,
#    'dew_point': 24.13,
#    'uvi': 0,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 9.57,
#    'wind_deg': 330,
#    'wind_gust': 17.02,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699437600,
#    'temp': 32.79,
#    'feels_like': 25.45,
#    'pressure': 1020,
#    'humidity': 72,
#    'dew_point': 23.85,
#    'uvi': 0,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 8.61,
#    'wind_deg': 342,
#    'wind_gust': 16.71,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699441200,
#    'temp': 31.42,
#    'feels_like': 24.78,
#    'pressure': 1021,
#    'humidity': 74,
#    'dew_point': 23.23,
#    'uvi': 0,
#    'clouds': 82,
#    'visibility': 10000,
#    'wind_speed': 7.02,
#    'wind_deg': 342,
#    'wind_gust': 15.73,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1699444800,
#    'temp': 30.18,
#    'feels_like': 24.75,
#    'pressure': 1022,
#    'humidity': 75,
#    'dew_point': 22.42,
#    'uvi': 0,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 5.21,
#    'wind_deg': 350,
#    'wind_gust': 12.84,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699448400,
#    'temp': 31.53,
#    'feels_like': 25.32,
#    'pressure': 1023,
#    'humidity': 68,
#    'dew_point': 21.2,
#    'uvi': 0.16,
#    'clouds': 64,
#    'visibility': 10000,
#    'wind_speed': 6.46,
#    'wind_deg': 5,
#    'wind_gust': 13.29,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699452000,
#    'temp': 33.06,
#    'feels_like': 26.8,
#    'pressure': 1023,
#    'humidity': 61,
#    'dew_point': 20.34,
#    'uvi': 0.55,
#    'clouds': 78,
#    'visibility': 10000,
#    'wind_speed': 6.98,
#    'wind_deg': 357,
#    'wind_gust': 11.52,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699455600,
#    'temp': 34.72,
#    'feels_like': 28.74,
#    'pressure': 1023,
#    'humidity': 55,
#    'dew_point': 19.56,
#    'uvi': 1.15,
#    'clouds': 82,
#    'visibility': 10000,
#    'wind_speed': 7.05,
#    'wind_deg': 349,
#    'wind_gust': 10.42,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699459200,
#    'temp': 36.52,
#    'feels_like': 31.53,
#    'pressure': 1023,
#    'humidity': 50,
#    'dew_point': 18.64,
#    'uvi': 1.55,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 6.11,
#    'wind_deg': 349,
#    'wind_gust': 8.81,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699462800,
#    'temp': 38.14,
#    'feels_like': 34.12,
#    'pressure': 1022,
#    'humidity': 45,
#    'dew_point': 17.96,
#    'uvi': 1.79,
#    'clouds': 88,
#    'visibility': 10000,
#    'wind_speed': 5.21,
#    'wind_deg': 349,
#    'wind_gust': 6.96,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699466400,
#    'temp': 39.18,
#    'feels_like': 35.17,
#    'pressure': 1022,
#    'humidity': 43,
#    'dew_point': 17.64,
#    'uvi': 1.63,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 5.46,
#    'wind_deg': 355,
#    'wind_gust': 7.27,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1699470000,
#    'temp': 39.36,
#    'feels_like': 36.93,
#    'pressure': 1021,
#    'humidity': 42,
#    'dew_point': 17.2,
#    'uvi': 1.12,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.65,
#    'wind_deg': 11,
#    'wind_gust': 4.56,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1699286400,
#    'sunrise': 1699271114,
#    'sunset': 1699307470,
#    'moonrise': 0,
#    'moonset': 1699298100,
#    'moon_phase': 0.79,
#    'temp': {'day': 48.51,
#     'min': 37.58,
#     'max': 50.83,
#     'night': 49.84,
#     'eve': 50.38,
#     'morn': 37.58},
#    'feels_like': {'day': 45.1, 'night': 42.98, 'eve': 47.89, 'morn': 34.95},
#    'pressure': 1018,
#    'humidity': 57,
#    'dew_point': 33.22,
#    'wind_speed': 22.32,
#    'wind_deg': 188,
#    'wind_gust': 43.44,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 1.57,
#    'uvi': 1.02},
#   {'dt': 1699372800,
#    'sunrise': 1699357592,
#    'sunset': 1699393800,
#    'moonrise': 1699335720,
#    'moonset': 1699385700,
#    'moon_phase': 0.82,
#    'temp': {'day': 53.31,
#     'min': 39.63,
#     'max': 55.38,
#     'night': 39.63,
#     'eve': 44.89,
#     'morn': 53.17},
#    'feels_like': {'day': 52.02, 'night': 32.47, 'eve': 38.12, 'morn': 51.94},
#    'pressure': 1007,
#    'humidity': 78,
#    'dew_point': 45.68,
#    'wind_speed': 19.77,
#    'wind_deg': 192,
#    'wind_gust': 39.3,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 62,
#    'pop': 0.92,
#    'rain': 1.71,
#    'uvi': 1.04},
#   {'dt': 1699459200,
#    'sunrise': 1699444070,
#    'sunset': 1699480131,
#    'moonrise': 1699425900,
#    'moonset': 1699473180,
#    'moon_phase': 0.85,
#    'temp': {'day': 36.52,
#     'min': 30.18,
#     'max': 39.65,
#     'night': 33.93,
#     'eve': 37.67,
#     'morn': 32.79},
#    'feels_like': {'day': 31.53, 'night': 28.94, 'eve': 37.67, 'morn': 25.45},
#    'pressure': 1023,
#    'humidity': 50,
#    'dew_point': 18.64,
#    'wind_speed': 11.18,
#    'wind_deg': 323,
#    'wind_gust': 18.32,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 86,
#    'pop': 1,
#    'rain': 4.54,
#    'snow': 0.14,
#    'uvi': 1.79},
#   {'dt': 1699545600,
#    'sunrise': 1699530548,
#    'sunset': 1699566464,
#    'moonrise': 1699516020,
#    'moonset': 1699560660,
#    'moon_phase': 0.88,
#    'temp': {'day': 49.26,
#     'min': 33.85,
#     'max': 55.69,
#     'night': 47.05,
#     'eve': 49.86,
#     'morn': 39.43},
#    'feels_like': {'day': 43.84, 'night': 44.04, 'eve': 45.48, 'morn': 31.73},
#    'pressure': 1006,
#    'humidity': 89,
#    'dew_point': 45.41,
#    'wind_speed': 14.43,
#    'wind_deg': 180,
#    'wind_gust': 34,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 98,
#    'pop': 1,
#    'rain': 13.87,
#    'uvi': 0.4},
#   {'dt': 1699632000,
#    'sunrise': 1699617026,
#    'sunset': 1699652798,
#    'moonrise': 1699606260,
#    'moonset': 1699648140,
#    'moon_phase': 0.91,
#    'temp': {'day': 45.77,
#     'min': 40.59,
#     'max': 48.43,
#     'night': 42.98,
#     'eve': 46.33,
#     'morn': 44.64},
#    'feels_like': {'day': 39.87, 'night': 37.31, 'eve': 41.95, 'morn': 39.61},
#    'pressure': 1015,
#    'humidity': 67,
#    'dew_point': 34.72,
#    'wind_speed': 12.77,
#    'wind_deg': 262,
#    'wind_gust': 24.74,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 81,
#    'pop': 0.2,
#    'uvi': 1.34},
#   {'dt': 1699718400,
#    'sunrise': 1699703504,
#    'sunset': 1699739134,
#    'moonrise': 1699696560,
#    'moonset': 1699735740,
#    'moon_phase': 0.94,
#    'temp': {'day': 37.54,
#     'min': 34.34,
#     'max': 41.36,
#     'night': 35.11,
#     'eve': 38.55,
#     'morn': 39.49},
#    'feels_like': {'day': 30.06, 'night': 31.53, 'eve': 31.71, 'morn': 32.72},
#    'pressure': 1023,
#    'humidity': 90,
#    'dew_point': 34.09,
#    'wind_speed': 13.35,
#    'wind_deg': 272,
#    'wind_gust': 27,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 100,
#    'pop': 0.63,
#    'rain': 1.55,
#    'snow': 0.23,
#    'uvi': 2},
#   {'dt': 1699804800,
#    'sunrise': 1699789982,
#    'sunset': 1699825473,
#    'moonrise': 1699787040,
#    'moonset': 1699823520,
#    'moon_phase': 0.98,
#    'temp': {'day': 35.53,
#     'min': 29.82,
#     'max': 39.31,
#     'night': 30.49,
#     'eve': 37.27,
#     'morn': 29.82},
#    'feels_like': {'day': 31.87, 'night': 30.49, 'eve': 32.95, 'morn': 29.82},
#    'pressure': 1036,
#    'humidity': 71,
#    'dew_point': 26.19,
#    'wind_speed': 5.7,
#    'wind_deg': 326,
#    'wind_gust': 7.94,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 2},
#   {'dt': 1699891200,
#    'sunrise': 1699876459,
#    'sunset': 1699911812,
#    'moonrise': 1699877700,
#    'moonset': 1699911600,
#    'moon_phase': 0,
#    'temp': {'day': 37.58,
#     'min': 28.98,
#     'max': 42.53,
#     'night': 38.46,
#     'eve': 39.09,
#     'morn': 29.14},
#    'feels_like': {'day': 35.15, 'night': 38.46, 'eve': 35.51, 'morn': 29.14},
#    'pressure': 1031,
#    'humidity': 52,
#    'dew_point': 20.98,
#    'wind_speed': 5.37,
#    'wind_deg': 121,
#    'wind_gust': 11.83,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 75,
#    'pop': 0.67,
#    'rain': 1.53,
#    'uvi': 2}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily']
# Out:
# [{'dt': 1699286400,
#   'sunrise': 1699271114,
#   'sunset': 1699307470,
#   'moonrise': 0,
#   'moonset': 1699298100,
#   'moon_phase': 0.79,
#   'temp': {'day': 48.51,
#    'min': 37.58,
#    'max': 50.83,
#    'night': 49.84,
#    'eve': 50.38,
#    'morn': 37.58},
#   'feels_like': {'day': 45.1, 'night': 42.98, 'eve': 47.89, 'morn': 34.95},
#   'pressure': 1018,
#   'humidity': 57,
#   'dew_point': 33.22,
#   'wind_speed': 22.32,
#   'wind_deg': 188,
#   'wind_gust': 43.44,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': 100,
#   'pop': 1,
#   'rain': 1.57,
#   'uvi': 1.02},
#  {'dt': 1699372800,
#   'sunrise': 1699357592,
#   'sunset': 1699393800,
#   'moonrise': 1699335720,
#   'moonset': 1699385700,
#   'moon_phase': 0.82,
#   'temp': {'day': 53.31,
#    'min': 39.63,
#    'max': 55.38,
#    'night': 39.63,
#    'eve': 44.89,
#    'morn': 53.17},
#   'feels_like': {'day': 52.02, 'night': 32.47, 'eve': 38.12, 'morn': 51.94},
#   'pressure': 1007,
#   'humidity': 78,
#   'dew_point': 45.68,
#   'wind_speed': 19.77,
#   'wind_deg': 192,
#   'wind_gust': 39.3,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 62,
#   'pop': 0.92,
#   'rain': 1.71,
#   'uvi': 1.04},
#  {'dt': 1699459200,
#   'sunrise': 1699444070,
#   'sunset': 1699480131,
#   'moonrise': 1699425900,
#   'moonset': 1699473180,
#   'moon_phase': 0.85,
#   'temp': {'day': 36.52,
#    'min': 30.18,
#    'max': 39.65,
#    'night': 33.93,
#    'eve': 37.67,
#    'morn': 32.79},
#   'feels_like': {'day': 31.53, 'night': 28.94, 'eve': 37.67, 'morn': 25.45},
#   'pressure': 1023,
#   'humidity': 50,
#   'dew_point': 18.64,
#   'wind_speed': 11.18,
#   'wind_deg': 323,
#   'wind_gust': 18.32,
#   'weather': [{'id': 616,
#     'main': 'Snow',
#     'description': 'rain and snow',
#     'icon': '13d'}],
#   'clouds': 86,
#   'pop': 1,
#   'rain': 4.54,
#   'snow': 0.14,
#   'uvi': 1.79},
#  {'dt': 1699545600,
#   'sunrise': 1699530548,
#   'sunset': 1699566464,
#   'moonrise': 1699516020,
#   'moonset': 1699560660,
#   'moon_phase': 0.88,
#   'temp': {'day': 49.26,
#    'min': 33.85,
#    'max': 55.69,
#    'night': 47.05,
#    'eve': 49.86,
#    'morn': 39.43},
#   'feels_like': {'day': 43.84, 'night': 44.04, 'eve': 45.48, 'morn': 31.73},
#   'pressure': 1006,
#   'humidity': 89,
#   'dew_point': 45.41,
#   'wind_speed': 14.43,
#   'wind_deg': 180,
#   'wind_gust': 34,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'clouds': 98,
#   'pop': 1,
#   'rain': 13.87,
#   'uvi': 0.4},
#  {'dt': 1699632000,
#   'sunrise': 1699617026,
#   'sunset': 1699652798,
#   'moonrise': 1699606260,
#   'moonset': 1699648140,
#   'moon_phase': 0.91,
#   'temp': {'day': 45.77,
#    'min': 40.59,
#    'max': 48.43,
#    'night': 42.98,
#    'eve': 46.33,
#    'morn': 44.64},
#   'feels_like': {'day': 39.87, 'night': 37.31, 'eve': 41.95, 'morn': 39.61},
#   'pressure': 1015,
#   'humidity': 67,
#   'dew_point': 34.72,
#   'wind_speed': 12.77,
#   'wind_deg': 262,
#   'wind_gust': 24.74,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': 81,
#   'pop': 0.2,
#   'uvi': 1.34},
#  {'dt': 1699718400,
#   'sunrise': 1699703504,
#   'sunset': 1699739134,
#   'moonrise': 1699696560,
#   'moonset': 1699735740,
#   'moon_phase': 0.94,
#   'temp': {'day': 37.54,
#    'min': 34.34,
#    'max': 41.36,
#    'night': 35.11,
#    'eve': 38.55,
#    'morn': 39.49},
#   'feels_like': {'day': 30.06, 'night': 31.53, 'eve': 31.71, 'morn': 32.72},
#   'pressure': 1023,
#   'humidity': 90,
#   'dew_point': 34.09,
#   'wind_speed': 13.35,
#   'wind_deg': 272,
#   'wind_gust': 27,
#   'weather': [{'id': 616,
#     'main': 'Snow',
#     'description': 'rain and snow',
#     'icon': '13d'}],
#   'clouds': 100,
#   'pop': 0.63,
#   'rain': 1.55,
#   'snow': 0.23,
#   'uvi': 2},
#  {'dt': 1699804800,
#   'sunrise': 1699789982,
#   'sunset': 1699825473,
#   'moonrise': 1699787040,
#   'moonset': 1699823520,
#   'moon_phase': 0.98,
#   'temp': {'day': 35.53,
#    'min': 29.82,
#    'max': 39.31,
#    'night': 30.49,
#    'eve': 37.27,
#    'morn': 29.82},
#   'feels_like': {'day': 31.87, 'night': 30.49, 'eve': 32.95, 'morn': 29.82},
#   'pressure': 1036,
#   'humidity': 71,
#   'dew_point': 26.19,
#   'wind_speed': 5.7,
#   'wind_deg': 326,
#   'wind_gust': 7.94,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': 100,
#   'pop': 0,
#   'uvi': 2},
#  {'dt': 1699891200,
#   'sunrise': 1699876459,
#   'sunset': 1699911812,
#   'moonrise': 1699877700,
#   'moonset': 1699911600,
#   'moon_phase': 0,
#   'temp': {'day': 37.58,
#    'min': 28.98,
#    'max': 42.53,
#    'night': 38.46,
#    'eve': 39.09,
#    'morn': 29.14},
#   'feels_like': {'day': 35.15, 'night': 38.46, 'eve': 35.51, 'morn': 29.14},
#   'pressure': 1031,
#   'humidity': 52,
#   'dew_point': 20.98,
#   'wind_speed': 5.37,
#   'wind_deg': 121,
#   'wind_gust': 11.83,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 75,
#   'pop': 0.67,
#   'rain': 1.53,
#   'uvi': 2}]

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) :  Miami, FL
# Current conditions in Miami, FL are broken clouds with a temperature of 82.18 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', continuous_update=False, description='location'), Button(description='Run…
