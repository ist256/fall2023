# %%
import requests

# %%
search = "who won the 2000 world series?"

apikey = "4c7694b7a039d5405b64cf03fa231fdadc4290608142bf613a3297bb90051a79"
url = "https://serpapi.com/search"
query_string = {
    'q': search,
    'api_key': apikey
}
response = requests.get(url, params=query_string)
response.raise_for_status()
data = response.json()

# %%
data
# Out:
# {'search_metadata': {'id': '6552941c3e86acd0f4d2aecc',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/3d26f7e8567f9736/6552941c3e86acd0f4d2aecc.json',
#   'created_at': '2023-11-13 21:24:44 UTC',
#   'processed_at': '2023-11-13 21:24:44 UTC',
#   'google_url': 'https://www.google.com/search?q=who+won+the+2000+world+series%3F&oq=who+won+the+2000+world+series%3F&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/3d26f7e8567f9736/6552941c3e86acd0f4d2aecc.html',
#   'total_time_taken': 1.8},
#  'search_parameters': {'engine': 'google',
#   'q': 'who won the 2000 world series?',
#   'google_domain': 'google.com',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'who won the 2000 world series?',
#   'total_results': 2230000000,
#   'time_taken_displayed': 0.39,
#   'menu_items': [{'position': 1,
#     'title': 'Images',
# ...
