# %%
import requests

key = "4c7694b7a039d5405b64cf03fa231fdadc4290608142bf613a3297bb90051a79"
url = "https://serpapi.com/search"
params = {
  'api_key': key,
  'engine': "google",
  'q': "who is the best NBA player?"
}

response = requests.get(url, params = params)
response.raise_for_status()
data = response.json()
data
# Out:
# {'search_metadata': {'id': '65528a9c1baebb6a0cbd03d1',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/5ff508ec7c995797/65528a9c1baebb6a0cbd03d1.json',
#   'created_at': '2023-11-13 20:44:12 UTC',
#   'processed_at': '2023-11-13 20:44:12 UTC',
#   'google_url': 'https://www.google.com/search?q=who+is+the+best+NBA+player%3F&oq=who+is+the+best+NBA+player%3F&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/5ff508ec7c995797/65528a9c1baebb6a0cbd03d1.html',
#   'total_time_taken': 4.52},
#  'search_parameters': {'engine': 'google',
#   'q': 'who is the best NBA player?',
#   'google_domain': 'google.com',
#   'device': 'desktop'},
#  'search_information': {'query_displayed': 'who is the best NBA player?',
#   'total_results': 415000000,
#   'time_taken_displayed': 0.52,
#   'menu_items': [{'position': 1, 'title': 'All'},
#    {'position': 2,
#     'title': 'News',
# ...
